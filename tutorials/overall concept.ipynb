# %% [markdown]
# # overall

# %%
import montage
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Input In [1], in <cell line: 3>()
#       2 sys.path.insert(0, "montages-master")
# ----> 3 import montages as montage
#
# File /idia/projects/hack4dev/dc1/tutorials/montages-master/montages/__init__.py:14, in <module>
#      13 import os
# ---> 14 import pims
#      15 import sys
#
# File ~/.local/lib/python3.8/site-packages/pims/__init__.py:1, in <module>
# ----> 1 from pims.api import *
#       3 from ._version import get_versions
#
# File ~/.local/lib/python3.8/site-packages/pims/api.py:13, in <module>
#      12 # has to be here for API stuff
# ---> 13 from pims.image_sequence import ImageSequence, ImageSequenceND, ReaderSequence  # noqa
#      14 from pims.image_reader import ImageReader, ImageReaderND  # noqa
#
# ...
